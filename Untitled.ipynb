# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv('Data/breast-cancer.csv')

# %%
data.columns
# Out:
# Index(['id', 'diagnosis', 'radius_mean', 'texture_mean', 'perimeter_mean',
#        'area_mean', 'smoothness_mean', 'compactness_mean', 'concavity_mean',
#        'concave points_mean', 'symmetry_mean', 'fractal_dimension_mean',
#        'radius_se', 'texture_se', 'perimeter_se', 'area_se', 'smoothness_se',
#        'compactness_se', 'concavity_se', 'concave points_se', 'symmetry_se',
#        'fractal_dimension_se', 'radius_worst', 'texture_worst',
#        'perimeter_worst', 'area_worst', 'smoothness_worst',
#        'compactness_worst', 'concavity_worst', 'concave points_worst',
#        'symmetry_worst', 'fractal_dimension_worst'],
#       dtype='object')

# %%
data.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
data['diagnosis'].value_counts()
# Out:
# B    357
# M    212
# Name: diagnosis, dtype: int64

# %%
x=data[data.columns[2:]]
col=np.array(x.columns).reshape(6,5)
fig, axes = plt.subplots(6, 5,figsize=(15, 15))
plt.figure(figsize=(15,20))
for i in range(6):
    for j in range(5):
        sns.boxplot(data=data, x='diagnosis', y=col[i][j], ax=axes[i,j])

# %%
sns.scatterplot(data=data,x='symmetry_se',y='fractal_dimension_se',hue='diagnosis');

# %%
sns.scatterplot(data=data,x='symmetry_worst',y='fractal_dimension_worst',hue='diagnosis');

# %%
sns.scatterplot(data=data,x='area_mean',y='area_worst',hue='diagnosis');

# %%
x.corr()
# Out:
#                          radius_mean  texture_mean  perimeter_mean  area_mean  \
# radius_mean                 1.000000      0.323782        0.997855   0.987357
# texture_mean                0.323782      1.000000        0.329533   0.321086
# perimeter_mean              0.997855      0.329533        1.000000   0.986507
# area_mean                   0.987357      0.321086        0.986507   1.000000
# smoothness_mean             0.170581     -0.023389        0.207278   0.177028
# compactness_mean            0.506124      0.236702        0.556936   0.498502
# concavity_mean              0.676764      0.302418        0.716136   0.685983
# concave points_mean         0.822529      0.293464        0.850977   0.823269
# symmetry_mean               0.147741      0.071401        0.183027   0.151293
# fractal_dimension_mean     -0.311631     -0.076437       -0.261477  -0.283110
# radius_se                   0.679090      0.275869        0.691765   0.732562
# ...

# %%
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2
select = SelectKBest(chi2, k=10)
y=data['diagnosis']
X_new=select.fit_transform(x, y)

# %%
X=np.array(data.iloc[:,2:])

# %%
mapper={'M':1,'B':0}
y=np.array(data['diagnosis'].map(mapper))

# %%
X_new.shape
# Out:
# (569, 10)

# %%
data.iloc[:,2:].columns[select.get_support()]
# Out:
# Index(['radius_mean', 'texture_mean', 'perimeter_mean', 'area_mean',
#        'perimeter_se', 'area_se', 'radius_worst', 'texture_worst',
#        'perimeter_worst', 'area_worst'],
#       dtype='object')

# %%
data_final=data[data.iloc[:,2:].columns[select.get_support()]]

# %%
data_final
# Out:
#      radius_mean  texture_mean  perimeter_mean  area_mean  perimeter_se  \
# 0          17.99         10.38          122.80     1001.0         8.589
# 1          20.57         17.77          132.90     1326.0         3.398
# 2          19.69         21.25          130.00     1203.0         4.585
# 3          11.42         20.38           77.58      386.1         3.445
# 4          20.29         14.34          135.10     1297.0         5.438
# ..           ...           ...             ...        ...           ...
# 564        21.56         22.39          142.00     1479.0         7.673
# 565        20.13         28.25          131.20     1261.0         5.203
# 566        16.60         28.08          108.30      858.1         3.425
# 567        20.60         29.33          140.10     1265.0         5.772
# 568         7.76         24.54           47.92      181.0         2.548
#
#      area_se  radius_worst  texture_worst  perimeter_worst  area_worst
# ...

# %% [markdown]
# # Building model

# %%
from sklearn.model_selection import train_test_split
X=np.array(data_final)
y=np.array(data['diagnosis'].map(mapper))
X_train, X_test, y_train, y_test = train_test_split(X, y,  test_size=0.2, random_state=0)

# %%
X_train.shape
# Out:
# (455, 10)

# %%
y_train.shape
# Out:
# (455,)

# %%
from sklearn.linear_model import LogisticRegression
classifier = LogisticRegression(max_iter=10000)
classifier.fit(X_train,y_train)
# Out:
# LogisticRegression(max_iter=10000)

# %%
y_pred = classifier.predict(X_test)
# print(np.concatenate((y_pred.reshape(len(y_pred),1), y_test.reshape(len(y_test),1)),1))

# %%
from sklearn.metrics import confusion_matrix, accuracy_score, roc_auc_score
cm7 = confusion_matrix(y_test, y_pred)
print(cm7)
# Out:
# [[62  5]
#  [ 1 46]]

# %%
logreg=accuracy_score(y_test,y_pred)
logreg
# Out:
# 0.9473684210526315

# %%
roc_auc_score(y_test, y_pred)
# Out:
# 0.9520482692918386

# %%
classifier.predict(X_test[0].reshape(1,-1))
# Out:
# array([1], dtype=int64)

# %%
import pickle
pickle.dump(classifier, open('model.pkl','wb'))
